# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='convenience' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    4969376422   None           None             None               None
# 1    4943537123   None           None             None               None
# 2    4391704241   None           None             None               None
# 3    4965049522   None           None             None               None
# 4    4391505191   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 221  2756199296   None           None             None               None
# 222  2711984737   None           None             None               None
# 223  1897440361   None           None             None               None
# 224  5929113019   None           None             None               None
# 225  3752440825   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle  \
# 0          None      None    None    None  None    None    None
# 1          None      None    None    None  None    None    None
# 2          None      None    None    None  None    None    None
# 3          None      None    None    None  None    None    None
# 4          None      None    None    None  None    None    None
# ..          ...       ...     ...     ...   ...     ...     ...
# 221        None      None    None    None  None    None    None
# 222        None      None    None    None  None    None    None
# 223        None      None    None    None  None    None    None
# 224        None      None    None    None  None    None    None
# 225        None      None    None    None  None    None    None
#
#               brand bridge boundary building capital construction covered  \
# 0              None   None     None     None    None         None    None
# 1              None   None     None     None    None         None    None
# 2              None   None     None     None    None         None    None
# 3              None   None     None     None    None         None    None
# 4              None   None     None     None    None         None    None
# ..              ...    ...      ...      ...     ...          ...     ...
# 221  NATURAL LAWSON   None     None     None    None         None    None
# 222        セブン-イレブン   None     None     None    None         None    None
# 223            ローソン   None     None     None    None         None    None
# 224        セブン-イレブン   None     None     None    None         None    None
# 225        セブン-イレブン   None     None     None    None         None    None
#
#     culvert cutting denomination disused   ele embankment  foot  \
# 0      None    None         None    None  None       None  None
# 1      None    None         None    None  None       None  None
# 2      None    None         None    None  None       None  None
# 3      None    None         None    None  None       None  None
# 4      None    None         None    None  None       None  None
# ..      ...     ...          ...     ...   ...        ...   ...
# 221    None    None         None    None  None       None  None
# 222    None    None         None    None  None       None  None
# 223    None    None         None    None  None       None  None
# 224    None    None         None    None  None       None  None
# 225    None    None         None    None  None       None  None
#
#     generator:source harbour highway historic horse intermittent junction  \
# 0               None    None    None     None  None         None     None
# 1               None    None    None     None  None         None     None
# 2               None    None    None     None  None         None     None
# 3               None    None    None     None  None         None     None
# 4               None    None    None     None  None         None     None
# ..               ...     ...     ...      ...   ...          ...      ...
# 221             None    None    None     None  None         None     None
# 222             None    None    None     None  None         None     None
# 223             None    None    None     None  None         None     None
# 224             None    None    None     None  None         None     None
# 225             None    None    None     None  None         None     None
#
#     landuse layer leisure  lock man_made military motorcar  \
# 0      None  None    None  None     None     None     None
# 1      None  None    None  None     None     None     None
# 2      None  None    None  None     None     None     None
# 3      None  None    None  None     None     None     None
# 4      None  None    None  None     None     None     None
# ..      ...   ...     ...   ...      ...      ...      ...
# 221    None  None    None  None     None     None     None
# 222    None  None    None  None     None     None     None
# 223    None  None    None  None     None     None     None
# 224    None  None    None  None     None     None     None
# 225    None  None    None  None     None     None     None
#
#                     name natural office oneway      operator place   poi  \
# 0    セブンイレブン千代田町なかさと公園前店    None   None   None          None  None  None
# 1               ファミリーマート    None   None   None          None  None  None
# 2                  セーブオン    None   None   None          None  None  None
# 3             ローソン館林野辺町店    None   None   None          None  None  None
# 4          セーブオン 千代田上中森店    None   None   None          None  None  None
# ..                   ...     ...    ...    ...           ...   ...   ...
# 221            ナチュラルローソン    None   None   None          ローソン  None  None
# 222             セブン-イレブン    None   None   None  セブンイレブン・ジャパン  None  None
# 223                 ローソン    None   None   None          None  None  None
# 224             セブン-イレブン    None   None   None          None  None  None
# 225             セブン-イレブン    None   None   None  セブンイレブン・ジャパン  None  None
#
#     population power power_source public_transport railway   ref religion  \
# 0         None  None         None             None    None  None     None
# 1         None  None         None             None    None  None     None
# 2         None  None         None             None    None  None     None
# 3         None  None         None             None    None  None     None
# 4         None  None         None             None    None  None     None
# ..         ...   ...          ...              ...     ...   ...      ...
# 221       None  None         None             None    None  None     None
# 222       None  None         None             None    None  None     None
# 223       None  None         None             None    None  None     None
# 224       None  None         None             None    None  None     None
# 225       None  None         None             None    None  None     None
#
#     route service         shop sport surface  toll tourism tower:type tunnel  \
# 0    None    None  convenience  None    None  None    None       None   None
# 1    None    None  convenience  None    None  None    None       None   None
# 2    None    None  convenience  None    None  None    None       None   None
# 3    None    None  convenience  None    None  None    None       None   None
# 4    None    None  convenience  None    None  None    None       None   None
# ..    ...     ...          ...   ...     ...   ...     ...        ...    ...
# 221  None    None  convenience  None    None  None    None       None   None
# 222  None    None  convenience  None    None  None    None       None   None
# 223  None    None  convenience  None    None  None    None       None   None
# 224  None    None  convenience  None    None  None    None       None   None
# 225  None    None  convenience  None    None  None    None       None   None
#
#     water waterway wetland width  wood z_order  \
# 0    None     None    None  None  None    None
# 1    None     None    None  None  None    None
# 2    None     None    None  None  None    None
# 3    None     None    None  None  None    None
# 4    None     None    None  None  None    None
# ..    ...      ...     ...   ...   ...     ...
# 221  None     None    None  None  None    None
# 222  None     None    None  None  None    None
# 223  None     None    None  None  None    None
# 224  None     None    None  None  None    None
# 225  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15520932.713 4331105.685)
# 1    POINT (15522925.833 4329987.306)
# 2    POINT (15524860.844 4330611.318)
# 3    POINT (15524943.799 4331073.879)
# 4    POINT (15525998.284 4327660.613)
# ..                                ...
# 221  POINT (15555970.768 4256638.578)
# 222  POINT (15555833.845 4256551.007)
# 223  POINT (15555868.799 4256491.202)
# 224  POINT (15555636.843 4256114.795)
# 225  POINT (15555917.513 4255888.617)
#
# [226 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_671457ec7347576c3cb390e811656d2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_671457ec7347576c3cb390e811656d2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_671457ec7347576c3cb390e811656d2b = L.map(
#                 &quot;map_671457ec7347576c3cb390e811656d2b&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec3dab220bf25eae1f6601bfdd6b9344 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#             var marker_1fa73103505468f8149d8bfb6667efb4 = L.marker(
#                 [36.22123399975823, 139.42691079999997],
#                 {}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#         var popup_61baf227901339ed1b821587e93107cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72bc95c86ba30936fd6fd074c4fb7098 = $(`&lt;div id=&quot;html_72bc95c86ba30936fd6fd074c4fb7098&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブンイレブン千代田町なかさと公園前店&lt;/div&gt;`)[0];
#                 popup_61baf227901339ed1b821587e93107cf.setContent(html_72bc95c86ba30936fd6fd074c4fb7098);
#
#
#
#         marker_1fa73103505468f8149d8bfb6667efb4.bindPopup(popup_61baf227901339ed1b821587e93107cf)
#         ;
#
#
#
#
#             var marker_e79013b14c5ec8909673818fa1497aa0 = L.marker(
#                 [36.21312859975737, 139.44481530000002],
#                 {}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#         var popup_d0d91b5516e2a402aba792eb7fbe10d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17278c054a1edb4e9176843bf2cac7f5 = $(`&lt;div id=&quot;html_17278c054a1edb4e9176843bf2cac7f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ファミリーマート&lt;/div&gt;`)[0];
#                 popup_d0d91b5516e2a402aba792eb7fbe10d3.setContent(html_17278c054a1edb4e9176843bf2cac7f5);
#
#
#
#         marker_e79013b14c5ec8909673818fa1497aa0.bindPopup(popup_d0d91b5516e2a402aba792eb7fbe10d3)
#         ;
#
#
#
#
#             var marker_54c5d46c7b4c243ece7b1be68f3979de = L.marker(
#                 [36.21765119975785, 139.46219779999998],
#                 {}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#         var popup_c6d04d82c3b211f85815dc7ca84b3ade = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79b3d5b6e26302edf77eac8e75148409 = $(`&lt;div id=&quot;html_79b3d5b6e26302edf77eac8e75148409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セーブオン&lt;/div&gt;`)[0];
#                 popup_c6d04d82c3b211f85815dc7ca84b3ade.setContent(html_79b3d5b6e26302edf77eac8e75148409);
#
#
#
#         marker_54c5d46c7b4c243ece7b1be68f3979de.bindPopup(popup_c6d04d82c3b211f85815dc7ca84b3ade)
#         ;
#
#
#
#
#             var marker_2c7cc103c38bef4864ed2bad68e67f6f = L.marker(
#                 [36.221003499758204, 139.462943],
#                 {}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#         var popup_82b698d5e1a55709209548a551a568a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eabf9d31a0abe5e4cb93aacf06b4d89d = $(`&lt;div id=&quot;html_eabf9d31a0abe5e4cb93aacf06b4d89d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ローソン館林野辺町店&lt;/div&gt;`)[0];
#                 popup_82b698d5e1a55709209548a551a568a4.setContent(html_eabf9d31a0abe5e4cb93aacf06b4d89d);
#
#
#
#         marker_2c7cc103c38bef4864ed2bad68e67f6f.bindPopup(popup_82b698d5e1a55709209548a551a568a4)
#         ;
#
#
#
#
#             var marker_1b3f3ebf5beb72ad2a3823840aee099d = L.marker(
#                 [36.1962632997556, 139.4724156],
#                 {}
#             ).addTo(map_671457ec7347576c3cb390e811656d2b);
#
#
#         var popup_12b239cd0ed0f02169713099381a3612 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3e2c4348554c8ebdbfc9c9cbf01e6ba = $(`&lt;div id=&quot;html_b3e2c4348554c8ebdbfc9c9cbf01e6ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セーブオン 千代田上中森店&lt;/div&gt;`)[0];
#                 popup_12b239cd0ed0f02169713099381a3612.setContent(html_b3e2c4348554c8ebdbfc9c9cbf01e6ba);
#
#
#
#         marker_1b3f3ebf5beb72ad2a3823840aee099d.bindPopup(popup_12b239cd0ed0f02169713099381a3612)
#         ;
#
#
#
#
#             var marker_f055f1266d0f91ad4e75a75830e0947b = L.marker(
